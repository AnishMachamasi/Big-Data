# %%
from confluent_kafka import Consumer
import pandas as pd
import json
import os
from minio import Minio
from minio.error import S3Error
import io

# MinIO configuration
MINIO_ENDPOINT = 'myminio:9000'  # Replace with your MinIO endpoint
MINIO_ACCESS_KEY = 'minio'    # Replace with your MinIO access key
MINIO_SECRET_KEY = 'minio123'    # Replace with your MinIO secret key
MINIO_BUCKET_NAME = 'kafka'   # Replace with your bucket name

# Initialize MinIO client
minio_client = Minio(
    MINIO_ENDPOINT,
    access_key=MINIO_ACCESS_KEY,
    secret_key=MINIO_SECRET_KEY,
    secure=False  # Set to True if using HTTPS
)

def consume_data_from_kafka(topic):
    conf = {
        'bootstrap.servers': 'kafka:9092',
        'group.id': 'my-group',
        'auto.offset.reset': 'earliest'
    }
    consumer = Consumer(conf)
    consumer.subscribe([topic])

    try:
        while True:
            msg = consumer.poll(timeout=1.0)
            if msg is None:
                continue
            if msg.error():
                print(f"Consumer error: {msg.error()}")
                continue
            
            # Process message
            message_value = msg.value().decode('utf-8')
            print(f"Received message: {message_value}")

            # Assuming messages are JSON objects
            try:
                json_data = json.loads(message_value)
                save_to_minio(topic, json_data)
            except json.JSONDecodeError as e:
                print(f"Failed to decode JSON: {e}")

    except KeyboardInterrupt:
        print("Consuming interrupted.")
    finally:
        consumer.close()

def save_to_minio(stock_name, data):
    # Define a unique file name
    file_name = f'{stock_name}.csv'
    
    try:
        # Try to download the existing CSV file from MinIO
        try:
            response = minio_client.get_object(MINIO_BUCKET_NAME, file_name)
            df_existing = pd.read_csv(io.BytesIO(response.read()))
        except S3Error as e:
            if e.code == 'NoSuchKey':
                # File does not exist, so create an empty DataFrame
                df_existing = pd.DataFrame()
            else:
                raise
        
        # Convert data to DataFrame
        df_new = pd.DataFrame([data])
        
        # Concatenate with existing data
        df_combined = pd.concat([df_existing, df_new], ignore_index=True)
        
        # Save DataFrame to a temporary file
        temp_file_path = f'/tmp/{file_name}'
        df_combined.to_csv(temp_file_path, index=False)
        
        # Upload the updated CSV file to MinIO
        minio_client.fput_object(
            MINIO_BUCKET_NAME,
            file_name,
            temp_file_path
        )
        print(f"Uploaded {temp_file_path} to MinIO bucket {MINIO_BUCKET_NAME}")

    except S3Error as e:
        print(f"Error handling file in MinIO: {e}")

# %%
ticker = 'AAPL'
consume_data_from_kafka(f'{ticker}_stock')
# Out:
# Received message: {"Date": "2023-01-03T00:00:00-05:00", "Open": 129.0660783975807, "High": 129.68029653659528, "Low": 123.01300942940523, "Close": 123.90462493896484, "Volume": 112117500, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-04T00:00:00-05:00", "Open": 125.70767760201481, "High": 127.46118952184275, "Low": 123.91454504113075, "Close": 125.1826171875, "Volume": 89113600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-05T00:00:00-05:00", "Open": 125.94542736004992, "High": 126.57946337342895, "Low": 123.59751534617322, "Close": 123.85508728027344, "Volume": 80962700, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-06T00:00:00-05:00", "Open": 124.8358457242084, "High": 129.07595607919873, "Low": 123.72627912066334, "Close": 128.41220092773438, "Volume": 87754700, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-09T00:00:00-05:00", "Open": 129.25431194699144, "High": 132.16692012612083, "Low": 128.6797144387554, "Close": 128.93728637695312, "Volume": 70790800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-10T00:00:00-05:00", "Open": 129.04626472881955, "High": 130.0369469810136, "Low": 126.9262053137887, "Close": 129.5118865966797, "Volume": 63896200, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-11T00:00:00-05:00", "Open": 130.02705151489968, "High": 132.2659880647187, "Low": 129.24441915137652, "Close": 132.24618530273438, "Volume": 69458900, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-12T00:00:00-05:00", "Open": 132.63253773675518, "High": 133.00898669335612, "Low": 130.2152707507638, "Close": 132.1669158935547, "Volume": 71379600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-13T00:00:00-05:00", "Open": 130.79977520796027, "High": 133.66284628280778, "Low": 130.433227615719, "Close": 133.50433349609375, "Volume": 57809700, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-17T00:00:00-05:00", "Open": 133.57368200396823, "High": 136.01075173541284, "Low": 132.88020749163076, "Close": 134.67333984375, "Volume": 63646600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-18T00:00:00-05:00", "Open": 135.54514851402828, "High": 137.31846303544214, "Low": 133.77181887600344, "Close": 133.9501495361328, "Volume": 69672800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-19T00:00:00-05:00", "Open": 132.83066830844814, "High": 134.98044682181893, "Low": 132.5235592517681, "Close": 134.00958251953125, "Volume": 58280400, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-20T00:00:00-05:00", "Open": 134.01949425343062, "High": 136.7339690742396, "Low": 132.96937348173864, "Close": 136.58535766601562, "Volume": 80223600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-23T00:00:00-05:00", "Open": 136.83305066300062, "High": 141.98461132711176, "Low": 136.61509932182912, "Close": 139.79519653320312, "Volume": 81760300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-24T00:00:00-05:00", "Open": 139.002634110196, "High": 141.82608477309955, "Low": 138.99273272896158, "Close": 141.2019500732422, "Volume": 66435100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-25T00:00:00-05:00", "Open": 139.57722970140298, "High": 141.1028738036697, "Low": 137.51660868777418, "Close": 140.53819274902344, "Volume": 65799300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-26T00:00:00-05:00", "Open": 141.8359895668473, "High": 142.90592831379684, "Low": 140.57781875562705, "Close": 142.61863708496094, "Volume": 54105100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-27T00:00:00-05:00", "Open": 141.82607255467883, "High": 145.85814139515608, "Low": 141.7468161617938, "Close": 144.57025146484375, "Volume": 70555800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-30T00:00:00-05:00", "Open": 143.60933149150912, "High": 144.1938304963564, "Low": 141.51899096263912, "Close": 141.66758728027344, "Volume": 64015300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-01-31T00:00:00-05:00", "Open": 141.37036016421538, "High": 142.9950785198001, "Low": 140.9542754152182, "Close": 142.94554138183594, "Volume": 65874500, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-01T00:00:00-05:00", "Open": 142.62851784574306, "High": 145.24391825462402, "Low": 140.00321605682092, "Close": 144.0749053955078, "Volume": 77663600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-02T00:00:00-05:00", "Open": 147.5125952216493, "High": 149.7713497604177, "Low": 146.78940134197146, "Close": 149.4147186279297, "Volume": 118339000, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-03T00:00:00-05:00", "Open": 146.6506794788317, "High": 155.913563755796, "Low": 146.4525460694196, "Close": 153.06039428710938, "Volume": 154357300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-06T00:00:00-05:00", "Open": 151.14839243295378, "High": 151.67345279630499, "Low": 149.37506280709064, "Close": 150.3162078857422, "Volume": 69858300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-07T00:00:00-05:00", "Open": 149.23636936430097, "High": 153.7835971367229, "Low": 149.23636936430097, "Close": 153.20899963378906, "Volume": 83322600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-08T00:00:00-05:00", "Open": 152.4461995562201, "High": 153.13967415379201, "Low": 149.76144382973365, "Close": 150.50445556640625, "Volume": 64120100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-09T00:00:00-05:00", "Open": 152.3471225123795, "High": 152.89200079937044, "Low": 149.01842938784935, "Close": 149.4642333984375, "Volume": 56007100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-10T00:00:00-05:00", "Open": 148.29346974183315, "High": 150.15878602646848, "Low": 148.05533749414406, "Close": 149.83135986328125, "Volume": 57450700, "Dividends": 0.23, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-13T00:00:00-05:00", "Open": 149.7718110044739, "High": 153.05597356686835, "Low": 149.74204636986607, "Close": 152.64918518066406, "Volume": 62199000, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-14T00:00:00-05:00", "Open": 150.93268488245778, "High": 152.5698155679683, "Low": 149.68252474599845, "Close": 152.00425720214844, "Volume": 61707600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-15T00:00:00-05:00", "Open": 151.91495619615625, "High": 154.28630131495925, "Low": 151.68675561660484, "Close": 154.1176300048828, "Volume": 65573800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-16T00:00:00-05:00", "Open": 152.31181809355212, "High": 155.10981469285346, "Low": 152.1530784319302, "Close": 152.51026916503906, "Volume": 68167900, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-17T00:00:00-05:00", "Open": 151.1608932791744, "High": 151.8058138835873, "Low": 149.67260098619803, "Close": 151.3593292236328, "Volume": 59144100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-21T00:00:00-05:00", "Open": 149.02766709322853, "High": 150.11908751084502, "Low": 147.25164492968057, "Close": 147.3210906982422, "Volume": 58867200, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-22T00:00:00-05:00", "Open": 147.70806068088748, "High": 148.77963306772958, "Low": 146.01141575649117, "Close": 147.7477569580078, "Volume": 51011300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-23T00:00:00-05:00", "Open": 148.91850350532056, "High": 149.16655218800904, "Low": 146.09075760648614, "Close": 148.23388671875, "Volume": 48394200, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-24T00:00:00-05:00", "Open": 145.96178276675255, "High": 146.04116017030702, "Low": 144.58263255183843, "Close": 145.56491088867188, "Volume": 55469600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-27T00:00:00-05:00", "Open": 146.5571047176501, "High": 148.00570068842444, "Low": 146.29912437294584, "Close": 146.7654571533203, "Volume": 44998500, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-02-28T00:00:00-05:00", "Open": 145.9022544419719, "High": 147.91640875864755, "Low": 145.68397036570926, "Close": 146.2594451904297, "Volume": 50547000, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-01T00:00:00-05:00", "Open": 145.6839673934971, "High": 146.08083926604587, "Low": 143.8781655521099, "Close": 144.1758270263672, "Volume": 55479000, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-02T00:00:00-05:00", "Open": 143.2531069289366, "High": 145.5649229017897, "Low": 142.77684246830484, "Close": 144.7711639404297, "Volume": 52238100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-03T00:00:00-05:00", "Open": 146.88451309635926, "High": 149.93055843188256, "Low": 146.1800632590767, "Close": 149.85118103027344, "Volume": 70732300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-06T00:00:00-05:00", "Open": 152.58963722441146, "High": 155.08005595311155, "Low": 152.26222625133693, "Close": 152.62933349609375, "Volume": 87558000, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-07T00:00:00-05:00", "Open": 152.50033271573355, "High": 152.82775880572618, "Low": 149.95040003625013, "Close": 150.41673278808594, "Volume": 56182000, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-08T00:00:00-05:00", "Open": 151.61728958019503, "High": 152.27214180165166, "Low": 150.64494288571473, "Close": 151.67681884765625, "Volume": 47204800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-09T00:00:00-05:00", "Open": 152.36144715352594, "High": 153.3337939210827, "Low": 149.05743630389182, "Close": 149.4146270751953, "Volume": 53833600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-10T00:00:00-05:00", "Open": 149.03760232020056, "High": 149.76190035677317, "Low": 146.45788952900153, "Close": 147.3409423828125, "Volume": 68572400, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-13T00:00:00-04:00", "Open": 146.6563207662423, "High": 151.94472122041284, "Low": 146.54717872536102, "Close": 149.29556274414062, "Volume": 84457100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-14T00:00:00-04:00", "Open": 150.09924442723477, "High": 152.20269278687886, "Low": 148.92846170318919, "Close": 151.39901733398438, "Volume": 73695900, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-15T00:00:00-04:00", "Open": 150.0099446456098, "High": 152.05386365311495, "Low": 148.74985292304112, "Close": 151.7958984375, "Volume": 77167900, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-16T00:00:00-04:00", "Open": 150.9723739729869, "High": 155.2388149114122, "Low": 150.45642840516308, "Close": 154.63357543945312, "Volume": 76161100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-17T00:00:00-04:00", "Open": 154.86176383478207, "High": 155.5166160263031, "Low": 153.07581019412967, "Close": 153.79019165039062, "Volume": 98944600, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-20T00:00:00-04:00", "Open": 153.85966233988228, "High": 156.5881981717665, "Low": 152.94682975683216, "Close": 156.1714630126953, "Volume": 73641400, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-21T00:00:00-04:00", "Open": 156.09209558103038, "High": 158.1558474735423, "Low": 155.31816969672417, "Close": 158.0367889404297, "Volume": 73938300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-22T00:00:00-04:00", "Open": 158.05665704613958, "High": 160.8744870435717, "Low": 156.57828113453724, "Close": 156.59812927246094, "Volume": 75701800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-23T00:00:00-04:00", "Open": 157.5903037627987, "High": 160.2890748618618, "Low": 156.44927064550194, "Close": 157.68951416015625, "Volume": 67622100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-24T00:00:00-04:00", "Open": 157.6200867175283, "High": 159.08853097045545, "Low": 156.61797529149237, "Close": 158.99923706054688, "Volume": 59196500, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-27T00:00:00-04:00", "Open": 158.69164854376666, "High": 159.51517209543513, "Low": 156.63779791375754, "Close": 157.0446014404297, "Volume": 52390300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-28T00:00:00-04:00", "Open": 156.73700421260284, "High": 157.2529497162647, "Low": 154.76253123067644, "Close": 156.41949462890625, "Volume": 45992200, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-29T00:00:00-04:00", "Open": 158.12610051487536, "High": 159.79299586322693, "Low": 158.106267516934, "Close": 159.5151824951172, "Volume": 51305700, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-30T00:00:00-04:00", "Open": 160.26923462761866, "High": 161.20190021896877, "Low": 160.01126941414205, "Close": 161.09275817871094, "Volume": 49501700, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-03-31T00:00:00-04:00", "Open": 161.17215439286315, "High": 163.71217111016068, "Low": 160.6462922665333, "Close": 163.61294555664062, "Volume": 68749800, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-04-03T00:00:00-04:00", "Open": 162.98785219887395, "High": 164.99207489468412, "Low": 162.9382394284507, "Close": 164.87301635742188, "Volume": 56976200, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-04-04T00:00:00-04:00", "Open": 165.29968004125942, "High": 165.53779713310735, "Low": 163.8213041573672, "Close": 164.33724975585938, "Volume": 46278300, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-04-05T00:00:00-04:00", "Open": 163.45418865732788, "High": 163.76176664528538, "Low": 160.5371333114085, "Close": 162.48182678222656, "Volume": 51511700, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-04-06T00:00:00-04:00", "Open": 161.16221135304366, "High": 163.67247839434094, "Low": 160.73557481041425, "Close": 163.37481689453125, "Volume": 45390100, "Dividends": 0.0, "Stock Splits": 0.0}
# Uploaded /tmp/AAPL_stock.csv to MinIO bucket kafka
# Received message: {"Date": "2023-04-10T00:00:00-04:00", "Open": 160.1600956010426, "High": 160.7653350830078, "Low": 158.8305580962968, "Close": 160.7653350830078, "Volume": 47716900, "Dividends": 0.0, "Stock Splits": 0.0}
